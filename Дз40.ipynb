# %% [markdown]
# # Домашнее задание. Свёрточные сети
#
# Здесь вам предстоит построить и обучить свою первую свёрточную сеть для классификации изображений на данных CIFAR10.

# %%
import tensorflow as tf

from tqdm import tqdm_notebook

# %% [markdown]
# ## Данные
#
# CIFAR10
# * 60000 RGB изображений размером 32x32x3
# * 10 классов: самолёты, собаки, рыбы и т.п.
#
# <img src="https://www.samyzaf.com/ML/cifar10/cifar1.jpg" style="width:60%">

# %% [markdown]
# Загрузите данные, разделите их на обучающую и тестовую выборки. Размер тестовой выборки должен быть $10^4$.

# %%
import numpy as np
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=10**4, random_state=42)

class_names = np.array(['airplane','automobile ','bird ','cat ','deer ','dog ','frog ','horse ','ship ','truck'])

print (X_train.shape,y_train.shape)
# Out:
# (40000, 32, 32, 3) (40000, 1)

# %% [markdown]
# Прежде чем приступать к основной работе, стоит убедиться что загруженно именно то, что требовалось:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.xlabel(class_names[y_train[i, 0]])
    plt.imshow(X_train[i])

# %% [markdown]
# ## Подготовка данных
#
# Сейчас каждый пиксель изображения закодирован тройкой чисел (RGB) __от 0 до 255__. Однако лучше себя показывает подход, где значения входов нейросети распределены недалеко от 0.
#
# Давайте приведём все данные в диапазон __`[0, 1]`__ — просто разделим на соответствующий коэффициент:

# %%
X_train = X_train / 255
X_val = X_val / 255
X_test = X_test / 255

# %% [markdown]
# Исполните код ниже для проверки, что все выполнено корректно.

# %%
assert np.shape(X_train) == (40000, 32, 32, 3), "data shape should not change"
assert 0.9 <= max(map(np.max, (X_train, X_val, X_test))) <= 1.05
assert 0.0 <= min(map(np.min, (X_train, X_val, X_test))) <= 0.1
assert len(np.unique(X_test / 255.)) > 10, "make sure you casted data to float type"

# %% [markdown]
# ## Архитектура сети
#
# Для начала реализуйте простую нейросеть:
# 1. принимает на вход картинки размера 32 x 32 x 3;
# 2. вытягивает их в вектор (`keras.layers.Flatten`);
# 3. пропускает через 1 или 2 полносвязных слоя;
# 4. выходной слой отдает вероятности принадлежности к каждому из 10 классов.

# %% [markdown]
# Создайте полносвязную сеть:

# %%
import keras
from keras import layers as L
from keras import backend as K

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=X_train.shape[1:]),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')

])

# %%
dummy_pred = model.predict(X_train[:20])
assert dummy_pred.shape == (20, 10)
assert np.allclose(dummy_pred.sum(-1), 1)
print("Успех!")
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Успех!

# %% [markdown]
# ## Обучение сети
#
# **Задание 1.1 (обязательно)** Будем минимизировать многоклассовую кроссэкнропию с помощью __sgd__. Вам нужно получить сеть, которая достигнет __не менее 45%__ __accuracy__ на тестовых данных.
#
# __Важно:__ поскольку в y_train лежат номера классов, Керасу нужно либо указать sparse функции потерь и метрики оценки качества классификации (`sparse_categorical_crossentropy` и `sparse_categorical_accuracy`), либо конвертировать метки в one-hot формат.
#
# ### Полезные советы
# * `model.compile` позволяет указать, какие метрики вы хотите вычислять.
# * В `model.fit` можно передать валидационную выборку (`validation_data=[X_val, y_val]`), для отслеживания прогресса на ней. Также рекомендуем сохранять результаты в [tensorboard](https://keras.io/callbacks/#tensorboard) или [wandb](https://docs.wandb.ai/integrations/jupyter). **Важно: логи tensorboard не получится без боли посмотреть через colab.** Workaround: скачать логи и запустить tensorboard локально или помучаться [с этим](https://stackoverflow.com/questions/47818822/can-i-use-tensorboard-with-google-colab).
# * По умолчанию сеть учится 1 эпоху. Совсем не факт, что вам этого хватит. Число эпох можно настроить в методе `fit` (`epochs`).
# * Ещё у Кераса есть много [полезных callback-ов](https://keras.io/callbacks/), которые можно попробовать. Например, автоматическая остановка или подбор скорости обучения.

# %%
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
             tf.keras.callbacks.TensorBoard(log_dir='./logs'),
             tf.keras.callbacks.EarlyStopping(patience=3)]

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics='sparse_categorical_accuracy')
model.fit(X_train, y_train, batch_size=16, epochs=32, callbacks=callbacks, validation_split=0.2)
# Out:
# Epoch 1/32
# 2000/2000 [==============================] - 18s 9ms/step - loss: 1.9486 - sparse_categorical_accuracy: 0.2872 - val_loss: 1.7809 - val_sparse_categorical_accuracy: 0.3478
# Epoch 2/32
# 2000/2000 [==============================] - 7s 4ms/step - loss: 1.7027 - sparse_categorical_accuracy: 0.3932 - val_loss: 1.6875 - val_sparse_categorical_accuracy: 0.3925
# Epoch 3/32
# 2000/2000 [==============================] - 5s 2ms/step - loss: 1.6040 - sparse_categorical_accuracy: 0.4291 - val_loss: 1.6038 - val_sparse_categorical_accuracy: 0.4335
# Epoch 4/32
# 2000/2000 [==============================] - 5s 2ms/step - loss: 1.5344 - sparse_categorical_accuracy: 0.4538 - val_loss: 1.5611 - val_sparse_categorical_accuracy: 0.4506
# Epoch 5/32
# 2000/2000 [==============================] - 5s 2ms/step - loss: 1.4817 - sparse_categorical_accuracy: 0.4749 - val_loss: 1.5274 - val_sparse_categorical_accuracy: 0.4512
# Epoch 6/32
# 2000/2000 [==============================] - 6s 3ms/step - loss: 1.4411 - sparse_categorical_accuracy: 0.4900 - val_loss: 1.5005 - val_sparse_categorical_accuracy: 0.4639
# Epoch 7/32
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.4022 - sparse_categorical_accuracy: 0.5021 - val_loss: 1.4677 - val_sparse_categorical_accuracy: 0.4785
# Epoch 8/32
# 2000/2000 [==============================] - 5s 3ms/step - loss: 1.3666 - sparse_categorical_accuracy: 0.5150 - val_loss: 1.4884 - val_sparse_categorical_accuracy: 0.4764
# Epoch 9/32
# 2000/2000 [==============================] - 6s 3ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.5273 - val_loss: 1.4349 - val_sparse_categorical_accuracy: 0.4936
# Epoch 10/32
# 2000/2000 [==============================] - 5s 3ms/step - loss: 1.3060 - sparse_categorical_accuracy: 0.5390 - val_loss: 1.4755 - val_sparse_categorical_accuracy: 0.4748
# Epoch 11/32
# 2000/2000 [==============================] - 6s 3ms/step - loss: 1.2767 - sparse_categorical_accuracy: 0.5474 - val_loss: 1.4749 - val_sparse_categorical_accuracy: 0.4775
# Epoch 12/32
# 2000/2000 [==============================] - 4s 2ms/step - loss: 1.2490 - sparse_categorical_accuracy: 0.5579 - val_loss: 1.4356 - val_sparse_categorical_accuracy: 0.4976

# %% [markdown]
# А теперь можно проверить качество вашей сети, выполнив код ниже:

# %%
from sklearn.metrics import accuracy_score

predict_x=model.predict(X_test)
classes_x=np.argmax(predict_x,axis=1)

test_acc = accuracy_score(y_test, classes_x)
print("\n Test_acc =", test_acc)
assert test_acc > 0.45, "Not good enough. Back to the drawing board :)"
print(" Not bad!")
# Out:
# 313/313 [==============================] - 5s 17ms/step
#
#  Test_acc = 0.5041
#  Not bad!

# %% [markdown]
# ## Карманная сверточная сеть
#
# **Задание 1.2 (обязательно)** Реализуйте небольшую свёрточную сеть. Совсем небольшую:
# 1. Входной слой
# 2. Свёртка 3x3 с 10 фильтрами
# 3. Нелинейность на ваш вкус
# 4. Max-pooling 2x2
# 5. Вытягиваем оставшееся в вектор (Flatten)
# 6. Полносвязный слой на 100 нейронов
# 7. Нелинейность на ваш вкус
# 8. Выходной полносвязный слой с softmax
#
# Обучите её так же, как и предыдущую сеть. Если всё хорошо, у вас получится accuracy не меньше __50%__.

# %%
## TODO
new_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
new_callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='new_model.{epoch:02d}-{val_loss:.2f}.h5'),
             tf.keras.callbacks.TensorBoard(log_dir='./logs'),
             tf.keras.callbacks.EarlyStopping(patience=3)]

# %%
new_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
new_model.fit(X_train, y_train, batch_size=16, epochs=32, callbacks=new_callbacks, validation_split=0.2)
# Out:
# Epoch 1/32
# 2000/2000 [==============================] - 7s 3ms/step - loss: 1.5923 - sparse_categorical_accuracy: 0.4299 - val_loss: 1.4259 - val_sparse_categorical_accuracy: 0.4900
# Epoch 2/32
# 2000/2000 [==============================] - 6s 3ms/step - loss: 1.2951 - sparse_categorical_accuracy: 0.5416 - val_loss: 1.2778 - val_sparse_categorical_accuracy: 0.5459
# Epoch 3/32
# 2000/2000 [==============================] - 5s 3ms/step - loss: 1.1749 - sparse_categorical_accuracy: 0.5861 - val_loss: 1.2519 - val_sparse_categorical_accuracy: 0.5602
# Epoch 4/32
# 2000/2000 [==============================] - 5s 2ms/step - loss: 1.0868 - sparse_categorical_accuracy: 0.6185 - val_loss: 1.1917 - val_sparse_categorical_accuracy: 0.5819
# Epoch 5/32
# 2000/2000 [==============================] - 5s 3ms/step - loss: 1.0173 - sparse_categorical_accuracy: 0.6442 - val_loss: 1.1732 - val_sparse_categorical_accuracy: 0.5997
# Epoch 6/32
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.9596 - sparse_categorical_accuracy: 0.6631 - val_loss: 1.1700 - val_sparse_categorical_accuracy: 0.5979
# Epoch 7/32
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.9100 - sparse_categorical_accuracy: 0.6796 - val_loss: 1.2120 - val_sparse_categorical_accuracy: 0.5956
# Epoch 8/32
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.8579 - sparse_categorical_accuracy: 0.6982 - val_loss: 1.1843 - val_sparse_categorical_accuracy: 0.6046
# Epoch 9/32
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.8092 - sparse_categorical_accuracy: 0.7155 - val_loss: 1.2206 - val_sparse_categorical_accuracy: 0.5838

# %% [markdown]
# Давайте посмотрим, смогла ли карманная сверточная сеть побить заданный порог по качеству:

# %%
from sklearn.metrics import accuracy_score

predict_x = new_model.predict(X_test)
classes_x = np.argmax(predict_x,axis=1)

test_acc = accuracy_score(y_test, classes_x)
print("\n Test_acc =", test_acc)
assert test_acc > 0.50, "Not good enough. Back to the drawing board :)"
print(" Not bad!")
# Out:
# 313/313 [==============================] - 1s 1ms/step
#
#  Test_acc = 0.5732
#  Not bad!

# %% [markdown]
# ## Учимся учить
#
# А теперь научимся сравнивать кривые обучения моделей — зависимости значения accuracy от количества итераций.
#
# Вам потребуется реализовать _экспериментальный стенд_ — вспомогательный код, в который вы сможете подать несколько архитектур и методов обучения, чтобы он их обучил и вывел графики кривых обучения. Это можно сделать с помощью `keras.callbacks` — `TensorBoard` или `History`.
#
# Будьте морально готовы, что на обучение уйдёт _много времени_. Даже если вы ограничитесь 10 эпохами. Пока идёт обучение, вы можете переключиться на другие задания или заняться чем-нибудь приятным: поспать, например.

# %% [markdown]
# **Задание 1.3 (опционально)** Попробуйте использовать различные методы оптимизации (sgd, momentum, adam) с параметрами по умолчанию. Какой из методов работает лучше?

# %% [markdown]
# Для удобства напишем класс Evaluator, который принимает в себя дикты виды {имя_оптимайзера: инстанс}, {имя модели: инстанс} и обучает всевозможные комбинации моделей с оптимайзерами при помощи метода fit (попутно записывая логи отдельно для каждой модели). Также пригодится метод evaluate для отображения итоговых скоров.

# %% [markdown]
# Пользоваться классом не обязательно. По умолчанию класс использует tensorboard. Если вы выше использовали wandb -- советуем дописать callback.

# %%
class Evaluator(list):
    def __init__(self, models, optimizers='adam', loss=keras.losses.categorical_crossentropy,
                 metrics=[keras.metrics.categorical_accuracy]):
        '''
            models: dict {name: model}
            optimizers: list of optimizers or just one optimizer
        '''
        if not isinstance(models, dict):
            models = {'single_model': models}
        if not isinstance(optimizers, dict):
            optimizers = {str(optimizers.__class__): optimizers}
        super().__init__([(model_name, keras.models.clone_model(model), optimizer_name, optimizer)
                          for model_name, model in models.items()
                          for optimizer_name, optimizer in optimizers.items()])
        for _, model, _, optimizer in self:
            model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def fit(self, X, y, validation_data=(), max_epochs=100, verbose=0, callbacks=[], batch_size=32):
        if not isinstance(callbacks, list):
            callbacks = [callbacks]
        for model_name, model, optimizer_name, optimizer in tqdm_notebook(self):
            model.fit(X, y, validation_data=validation_data or None, epochs=max_epochs, verbose=verbose,
                      batch_size=batch_size, callbacks=callbacks + [keras.callbacks.TensorBoard(
                          log_dir='./logs/{}_{}'.format(model_name, optimizer_name).replace('<', '').replace('>', ''))])
                          

    def fit_generator(self, X, y, validation_data=(), max_epochs=100, verbose=1, callbacks=[], batch_size=32):
        datagen = keras.preprocessing.image.ImageDataGenerator(
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True
        )
        if not isinstance(callbacks, list):
            callbacks = [callbacks]
        for model_name, model, optimizer_name, optimizer in tqdm_notebook(self):
            model.fit_generator(datagen.flow(X, y, batch_size=batch_size), epochs=max_epochs,
                validation_data=validation_data or None, verbose=verbose,
                callbacks=callbacks + [keras.callbacks.TensorBoard(
                    log_dir='./logs/{}_{}'.format(model_name, optimizer_name).replace('<', '').replace('>', ''))])

    def evaluate(self, X, y, metric):
        for model_name, model, optimizer_name, _ in self:
            print('Final score of {}_{} is {}'.format(model_name, optimizer_name,
                  metric(y_test, model.predict(X_test).argmax(axis=1))))

# %%
# !rm -rf ./logs

# %%
from tensorflow.keras import optimizers

## TODO
optimizers = {...}

# %%
evaluator = Evaluator(model, optimizers='adam')
y_train, y_val = (keras.utils.to_categorical(y) for y in (y_train, y_val))
evaluator.fit(X_train, y_train, validation_data=(X_val, y_val))
evaluator.evaluate(X_test, y_test, accuracy_score)

# %%
# !pwd

# %% [markdown]
# Прокомментируйте полученные результаты.

# %% [markdown]
# # __Работает бесконечно долго, не стал делать__

# %% [markdown]
# **Задание 1.4 (опционально)** Добавьте нормализацию по батчу (`BatchNormalization`) между свёрткой и активацией. Попробуйте использовать несколько нормализаций — в свёрточных и полносвязных слоях.

# %% [markdown]
# Для удобства реализуем класс Models, который по сути будет являться списком моделей с двумя методами: add (добавить слой ко всем моделям) и add_create (создать новую модель на основе базовой с дополнительным слоем). Пользоваться им необязательно, но вдруг :)

# %%
from collections import OrderedDict
from keras.layers import BatchNormalization

class Models(OrderedDict):
    def __init__(self, models):
        if not isinstance(models, dict):
            models = OrderedDict({'base_model': models})
        super().__init__(models)

    def add(self, layer):
        for name, model in self.items():
            model.add(layer)

    def add_create(self, name, layer):
        base_model = next(iter(self.items()))[1]
        new_model = keras.models.clone_model(base_model)
        new_model.add(layer)
        self.update({name: new_model})

    def add_update(self, name, layer):
        base_model = self[next(reversed(self))]
        new_model = keras.models.clone_model(base_model)
        new_model.add(layer)
        self.update({name: new_model})
    
    def add_batch_normalization(self, name, layer):
        for name, model in self.items():
            model(layer)
            model.add(BatchNormalization())

# Example of usage
models = Models(keras.Sequential())
models.add(L.InputLayer(input_shape=(32, 32, 3)))
models.add(L.Convolution2D(filters=10, kernel_size=(3, 3)))
models.add(L.MaxPooling2D())
models.add_create('conv_batchnorm', BatchNormalization())
models.add(L.Activation('relu'))

# %% [markdown]
# Прокомментируйте полученные результаты.

# %%
models

# %% [markdown]
# **Задание 1.5 (опционально)** Посмотрите на batch_size (параметр model.fit) - при большем батче модель будет быстрее проходить эпохи, но с совсем огромным батчом вам потребуется больше эпох для сходимости (т.к. сеть делает меньше шагов за одну эпоху).
# Найдите такое значение, при котором модель быстрее достигает точности 55%. **Hint**: используйте early stopping callback.

# %%
from keras.callbacks import EarlyStopping
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
dict_batch_size_epochs = {}

for i in range(16, 641, 16):
    for j in range(1, 33):
        model.reset_states()

        history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=i, epochs=j, callbacks=early_stopping, validation_split=0.2)
        if history.history['sparse_categorical_accuracy'][-1] >= 0.55:
            dict_batch_size_epochs[i] = j
            break
batch_size, epochs = 1, 32
for key, value in dict_batch_size_epochs.items():
    if value < epochs:
        epochs = value
        batch_size = key
print('Найденное значение batch_size:', batch_size)
print('Количество эпох:', epochs)
# Out:
# 2500/2500 [==============================] - 20s 8ms/step - loss: 1.5472 - sparse_categorical_accuracy: 0.4540 - val_loss: 1.5036 - val_sparse_categorical_accuracy: 0.4748
# Epoch 1/2
# 2500/2500 [==============================] - 11s 4ms/step - loss: 1.3939 - sparse_categorical_accuracy: 0.5071 - val_loss: 1.4671 - val_sparse_categorical_accuracy: 0.4879
# Epoch 2/2
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1
# 70/70 [==============================] - 6s 81ms/step - loss: 0.2028 - sparse_categorical_accuracy: 0.9419 - val_loss: 3.2131 - val_sparse_categorical_accuracy: 0.4738
# 68/68 [==============================] - 6s 84ms/step - loss: 0.1959 - sparse_categorical_accuracy: 0.9451 - val_loss: 3.2643 - val_sparse_categorical_accuracy: 0.4686
# 66/66 [==============================] - 6s 85ms/step - loss: 0.1858 - sparse_categorical_accuracy: 0.9484 - val_loss: 3.2964 - val_sparse_categorical_accuracy: 0.4735
# 65/65 [==============================] - 6s 88ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9502 - val_loss: 3.3620 - val_sparse_categorical_accuracy: 0.4746
# 63/63 [==============================] - 6s 89ms/step - loss: 0.1743 - sparse_categorical_accuracy: 0.9528 - val_loss: 3.4172 - val_sparse_categorical_accuracy: 0.4725
# Найденное значение batch_size: 32
# Количество эпох: 1

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=X_train.shape[1:]),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')

])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
early_stopping = EarlyStopping(monitor='sparse_categorical_accuracy', patience=2, restore_best_weights=True)
dict_batch_size_epochs = {}
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=32, batch_size=128, callbacks=early_stopping, validation_split=0.2)
# Out:
# Epoch 1/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.9256 - sparse_categorical_accuracy: 0.2845 - val_loss: 1.7529 - val_sparse_categorical_accuracy: 0.3492
# Epoch 2/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.6878 - sparse_categorical_accuracy: 0.3829 - val_loss: 1.6469 - val_sparse_categorical_accuracy: 0.3988
# Epoch 3/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.6077 - sparse_categorical_accuracy: 0.4150 - val_loss: 1.6078 - val_sparse_categorical_accuracy: 0.4185
# Epoch 4/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.5613 - sparse_categorical_accuracy: 0.4336 - val_loss: 1.5892 - val_sparse_categorical_accuracy: 0.4193
# Epoch 5/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.5319 - sparse_categorical_accuracy: 0.4459 - val_loss: 1.5534 - val_sparse_categorical_accuracy: 0.4416
# Epoch 6/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.5047 - sparse_categorical_accuracy: 0.4542 - val_loss: 1.5624 - val_sparse_categorical_accuracy: 0.4378
# Epoch 7/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4913 - sparse_categorical_accuracy: 0.4599 - val_loss: 1.5479 - val_sparse_categorical_accuracy: 0.4435
# Epoch 8/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4727 - sparse_categorical_accuracy: 0.4674 - val_loss: 1.5247 - val_sparse_categorical_accuracy: 0.4558
# Epoch 9/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.4575 - sparse_categorical_accuracy: 0.4734 - val_loss: 1.5511 - val_sparse_categorical_accuracy: 0.4399
# Epoch 10/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4458 - sparse_categorical_accuracy: 0.4817 - val_loss: 1.5288 - val_sparse_categorical_accuracy: 0.4517
# Epoch 11/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.4236 - sparse_categorical_accuracy: 0.4886 - val_loss: 1.5416 - val_sparse_categorical_accuracy: 0.4538
# Epoch 12/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.4017 - sparse_categorical_accuracy: 0.4992 - val_loss: 1.4995 - val_sparse_categorical_accuracy: 0.4731
# Epoch 13/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3835 - sparse_categorical_accuracy: 0.5063 - val_loss: 1.5121 - val_sparse_categorical_accuracy: 0.4647
# Epoch 14/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3703 - sparse_categorical_accuracy: 0.5127 - val_loss: 1.4918 - val_sparse_categorical_accuracy: 0.4723
# Epoch 15/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3539 - sparse_categorical_accuracy: 0.5159 - val_loss: 1.4936 - val_sparse_categorical_accuracy: 0.4698
# Epoch 16/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.3402 - sparse_categorical_accuracy: 0.5234 - val_loss: 1.4962 - val_sparse_categorical_accuracy: 0.4750
# Epoch 17/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.3326 - sparse_categorical_accuracy: 0.5251 - val_loss: 1.5015 - val_sparse_categorical_accuracy: 0.4785
# Epoch 18/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3163 - sparse_categorical_accuracy: 0.5322 - val_loss: 1.5126 - val_sparse_categorical_accuracy: 0.4694
# Epoch 19/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.3001 - sparse_categorical_accuracy: 0.5361 - val_loss: 1.5044 - val_sparse_categorical_accuracy: 0.4750
# Epoch 20/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2913 - sparse_categorical_accuracy: 0.5416 - val_loss: 1.5226 - val_sparse_categorical_accuracy: 0.4597
# Epoch 21/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2863 - sparse_categorical_accuracy: 0.5444 - val_loss: 1.5323 - val_sparse_categorical_accuracy: 0.4695
# Epoch 22/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2709 - sparse_categorical_accuracy: 0.5515 - val_loss: 1.5154 - val_sparse_categorical_accuracy: 0.4736
# Epoch 23/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2588 - sparse_categorical_accuracy: 0.5534 - val_loss: 1.5440 - val_sparse_categorical_accuracy: 0.4645
# Epoch 24/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2474 - sparse_categorical_accuracy: 0.5590 - val_loss: 1.5258 - val_sparse_categorical_accuracy: 0.4756
# Epoch 25/32
# 313/313 [==============================] - 5s 17ms/step - loss: 1.2408 - sparse_categorical_accuracy: 0.5607 - val_loss: 1.5413 - val_sparse_categorical_accuracy: 0.4645
# Epoch 26/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.2295 - sparse_categorical_accuracy: 0.5650 - val_loss: 1.5948 - val_sparse_categorical_accuracy: 0.4537
# Epoch 27/32
# 313/313 [==============================] - 5s 15ms/step - loss: 1.2173 - sparse_categorical_accuracy: 0.5692 - val_loss: 1.5541 - val_sparse_categorical_accuracy: 0.4689
# Epoch 28/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.2079 - sparse_categorical_accuracy: 0.5700 - val_loss: 1.5631 - val_sparse_categorical_accuracy: 0.4670
# Epoch 29/32
# 313/313 [==============================] - 6s 18ms/step - loss: 1.2004 - sparse_categorical_accuracy: 0.5756 - val_loss: 1.5817 - val_sparse_categorical_accuracy: 0.4590
# Epoch 30/32
# 313/313 [==============================] - 6s 19ms/step - loss: 1.1909 - sparse_categorical_accuracy: 0.5791 - val_loss: 1.5727 - val_sparse_categorical_accuracy: 0.4614
# Epoch 31/32
# 313/313 [==============================] - 5s 17ms/step - loss: 1.1755 - sparse_categorical_accuracy: 0.5830 - val_loss: 1.6029 - val_sparse_categorical_accuracy: 0.4556
# Epoch 32/32
# 313/313 [==============================] - 5s 16ms/step - loss: 1.1690 - sparse_categorical_accuracy: 0.5882 - val_loss: 1.6130 - val_sparse_categorical_accuracy: 0.4616

# %% [markdown]
# **Задание 1.6 (опционально)** Попробуйте найти такую комбинацию метода обучения и нормализации, при которой сеть имеет наилучшую кривую обучения. Поясните, что вы понимаете под "наилучшей" кривой обучения.

# %% [markdown]
# ## Свёрточная нейросеть здорового человека
#
# **Задание 1.7 (обязательно попытаться)** Наигравшись выше, обучим большую свёрточную сеть, которая даст на тестовой выборке __accuracy больше 80%__. В этом задании вам потребуется провести эксперименты, сравнив их между собой в конце. Возможно, может быть несколько проще, если писать выводы во время или сразу после каждого эксперимента, после чего сделать общие выводы.
#
# Рекомендуем начать с лучшей модели предыдущего задания и постепенно её улучшать. Вы можете использовать всё, что угодно: любые активации, сколь угодно большие свёрточные слои и глубокие сети. Единственное ограничение: __нельзя использовать предобученные сети и дополнительные данные__.
#
# ### Полезные советы
# * Для начала, неплохо бы научить что-нибудь побольше, чем 10 фильтров 3x3.
# * __Главное правило: одно изменение на эксперимент__. Если у вас есть 2 идеи по улучшению сети, сначала попробуйте их независимо. Может оказаться, что одно из них дало __+10%__ точности а другое __-7%__. А вы так и будете думать, что сделали 2 полезных изменения которые в сумме дают __+3%__. Если какая-то идея не работает — даже если она вам нравится - опишите ее и выкидывайте из дальнейших экспериментов.
# * __Be careful or you will dropout__. Дропаут (`L.Dropout`) может позволить вам обучить в несколько раз бОльшую сеть без переобучения, выжав несколько процентов качества. Это круто, но не стоит сразу ставить dropout 50%. Во-первых, слишком сильный дропаут только ухудшит сеть (underfitting). Во-вторых, даже если дропаут улучшает качество, он замедляет обучение. Рекомендуем начинать с небольшого дропаута, быстро провести основные эксперименты, а потом жахнуть в 2 раза больше нейронов и дропаута ~~на ночь~~.
# * __Аугментация данных__. Если котика слегка повернуть и подрезать (простите), он всё равно останется котиком. А в керасе есть [удобный класс](https://keras.io/preprocessing/image/), который поставит подрезание котиков на поток. Ещё можно сделать этот трюк в тесте: вертим картинку 10 раз, предсказываем вероятности и усредняем. Только один совет: прежде, чем учить, посмотрите глазами на аугментированные картинки. Если вы сами не можете их различить, то и сеть не сможет.
# * __Don't just stack more layers__. Есть более эффективные способы организовать слои, чем простой Sequential. Вот пара идей: [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions](https://arxiv.org/abs/1608.06993). Только не копируйте архитектуру подчистую — вам скорее всего хватит меньшего размера.
# * __Долго != плохо__. Более глубокие архитектуры обычно требуют бОльше эпох до сходимости. Это значит, что в первые несколько эпох они могут быть хуже менее глубоких аналогов. Дайте им время, запаситесь чаем и обмажьтесь batch-norm-ом.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

# %%
val_datagen = ImageDataGenerator()

split = 45000
dg_x_train, dg_x_val = X_train[:split], X_train[split:]
dg_y_train, dg_y_val = y_train[:split], y_train[split:]

# %%
final_model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(32, activation='relu', input_shape=X_train.shape[1:]),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')

])

# %%
final_callbacks = [tf.keras.callbacks.EarlyStopping(patience=5)]

# %%
tf.keras.utils.plot_model(final_model, '123.png', show_shapes=True)

# %%
## TODO
final_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='sparse_categorical_accuracy')
final_model.fit(datagen.flow(dg_x_train, dg_y_train, batch_size=16), epochs=32, callbacks=final_callbacks, validation_data=val_datagen.flow(dg_x_val, dg_y_val))
# Out:
# Epoch 1/32
# 2496/2500 [============================>.] - ETA: 0s - loss: 2.1659 - sparse_categorical_accuracy: 0.1694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 48s 19ms/step - loss: 2.1655 - sparse_categorical_accuracy: 0.1698
# Epoch 2/32
# 2497/2500 [============================>.] - ETA: 0s - loss: 1.7611 - sparse_categorical_accuracy: 0.3533WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 41s 17ms/step - loss: 1.7612 - sparse_categorical_accuracy: 0.3532
# Epoch 3/32
# 2500/2500 [==============================] - ETA: 0s - loss: 1.6790 - sparse_categorical_accuracy: 0.3899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 39s 16ms/step - loss: 1.6790 - sparse_categorical_accuracy: 0.3899
# Epoch 4/32
# 2498/2500 [============================>.] - ETA: 0s - loss: 1.6388 - sparse_categorical_accuracy: 0.4072WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] -
ARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 41s 16ms/step - loss: 1.5391 - sparse_categorical_accuracy: 0.4464
# Epoch 21/32
# 2498/2500 [============================>.] - ETA: 0s - loss: 1.5384 - sparse_categorical_accuracy: 0.4463WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 40s 16ms/step - loss: 1.5383 - sparse_categorical_accuracy: 0.4464
# Epoch 22/32
# 2496/2500 [============================>.] - ETA: 0s - loss: 1.5364 - sparse_categorical_accuracy: 0.4467WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 39s 16ms/step - loss: 1.5361 - sparse_categorical_accuracy: 0.4468
# Epoch 23/32
# 2499/2500 [============================>.] - ETA: 0s - loss: 1.5344 - sparse_categorical_accuracy: 0.4457WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 40s 16ms/step - loss: 1.5343 - sparse_categorical_accuracy: 0.4457
# Epoch 24/32
# 2500/2500 [==============================] - ETA: 0s - loss: 1.5332 - sparse_categorical_accuracy: 0.4468WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 39s 15ms/step - loss: 1.5332 - sparse_categorical_accuracy: 0.4468
# Epoch 25/32
# 2500/2500 [==============================] - ETA: 0s - loss: 1.5315 - sparse_categorical_accuracy: 0.4503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 38s 15ms/step - loss: 1.5315 - sparse_categorical_accuracy: 0.4503
# Epoch 26/32
# 2499/2500 [============================>.] - ETA: 0s - loss: 1.5263 - sparse_categorical_accuracy: 0.4495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 39s 16ms/step - loss: 1.5263 - sparse_categorical_accuracy: 0.4495
# Epoch 27/32
# 2495/2500 [============================>.] - ETA: 0s - loss: 1.5270 - sparse_categorical_accuracy: 0.4514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 39s 16ms/step - loss: 1.5266 - sparse_categorical_accuracy: 0.4516
# Epoch 28/32
# 2499/2500 [============================>.] - ETA: 0s - loss: 1.5239 - sparse_categorical_accuracy: 0.4551WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 38s 15ms/step - loss: 1.5239 - sparse_categorical_accuracy: 0.4551
# Epoch 29/32
# 2498/2500 [============================>.] - ETA: 0s - loss: 1.5177 - sparse_categorical_accuracy: 0.4563WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 38s 15ms/step - loss: 1.5177 - sparse_categorical_accuracy: 0.4564
# Epoch 30/32
# 2498/2500 [============================>.] - ETA: 0s - loss: 1.5174 - sparse_categorical_accuracy: 0.4545WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 38s 15ms/step - loss: 1.5174 - sparse_categorical_accuracy: 0.4546
# Epoch 31/32
# 2498/2500 [============================>.] - ETA: 0s - loss: 1.5173 - sparse_categorical_accuracy: 0.4519WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 38s 15ms/step - loss: 1.5171 - sparse_categorical_accuracy: 0.4520
# Epoch 32/32
# 2496/2500 [============================>.] - ETA: 0s - loss: 1.5163 - sparse_categorical_accuracy: 0.4577WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,sparse_categorical_accuracy
# 2500/2500 [==============================] - 39s 16ms/step - loss: 1.5163 - sparse_categorical_accuracy: 0.4579

# %% [markdown]
# Момент истины: проверьте, какого качества достигла ваша сеть.

# %%
from sklearn.metrics import accuracy_score

predict_x=final_model.predict(X_test)
classes_x=np.argmax(predict_x,axis=1)

test_acc = accuracy_score(y_test, classes_x)
print("\n Test_acc =", test_acc)
if test_acc > 0.8:
    print("Это победа!")
# Out:
# 313/313 [==============================] - 2s 6ms/step
#
#  Test_acc = 0.4714

# %% [markdown]
# А теперь, опишите свои <s>ощущения</s> результаты от проведенных экспериментов.
